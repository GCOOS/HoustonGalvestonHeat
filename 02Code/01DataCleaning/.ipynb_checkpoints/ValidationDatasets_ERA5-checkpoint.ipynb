# %% [markdown]
# ## Validation Datasets
#
# The goal is to compare station data to ERA5 data and buoy data to GHRSST data to see how much error we are getting in a sample of regions in our models
#
# From there, we can use that to figure out a reasonable "perturbation" for our model, changing 2m Temperature and SST accordingly to account for likely measurement error and use that to run ensemble models.

# %%
#import what you need
import xarray as xr #to read grib
import pandas as pd #for station data
import numpy as np #for subtracting arrays
from datetime import datetime, timedelta #to handle the dates
import statistics #to get mean and sd
from math import isnan #get rid of nas
from itertools import filterfalse #get rid of nas

# %%
## read in atmospheric data

#ERA5
era5_sfcMar = xr.load_dataset("../../01Data/SFC/ERA5_WRF_SFC_201703.grib", engine="cfgrib", decode_timedelta=True)
era5_sfcApr = xr.load_dataset("../../01Data/SFC/ERA5_WRF_SFC_201704.grib", engine="cfgrib", decode_timedelta=True)

#era5_plMar = xr.load_dataset("../../01Data/PLEV/ERA5_WRF_PLEV_201703.grib", engine="cfgrib")
#era5_plpr = xr.load_dataset("../../01Data/PLEV/ERA5_WRF_PLEV_201704.grib", engine="cfgrib")

#Station data
anglStation = pd.read_csv("../../01Data/ValidationDatasets/WeatherStations/AngletonLakeJackson/GHCNh_USW00012976_2017.psv", sep="|", low_memory=False)
beauStation = pd.read_csv("../../01Data/ValidationDatasets/WeatherStations/Beaumont/GHCNh_USW00000313_2017.psv", sep="|", low_memory=False)
conrStation = pd.read_csv("../../01Data/ValidationDatasets/WeatherStations/Conroe/GHCNh_USW00053902_2017.psv", sep="|", low_memory=False)
galvStation = pd.read_csv("../../01Data/ValidationDatasets/WeatherStations/Galveston/GHCNh_USW00012923_2017.psv", sep="|", low_memory=False)
housStation = pd.read_csv("../../01Data/ValidationDatasets/WeatherStations/Houston/GHCNh_USW00012975_2017.psv", sep="|", low_memory=False)

clvlStation = pd.read_csv("../../01Data/ValidationDatasets/WeatherStations/Cleveland/GHCNh_USW00000378_2017.psv", sep="|", low_memory=False)
hiolStation = pd.read_csv("../../01Data/ValidationDatasets/WeatherStations/HighIslandOil/GHCNh_USW00000306_2017.psv", sep="|", low_memory=False)
hseaStation = pd.read_csv("../../01Data/ValidationDatasets/WeatherStations/HoustonExecAP/GHCNh_USW00000208_2017.psv", sep="|", low_memory=False)
hsinStation = pd.read_csv("../../01Data/ValidationDatasets/WeatherStations/HoustonIntercontl/GHCNh_USW00012960_2017.psv", sep="|", low_memory=False)
hntsStation = pd.read_csv("../../01Data/ValidationDatasets/WeatherStations/Huntsville/GHCNh_USW00053903_2017.psv", sep="|", low_memory=False)
ptarStation = pd.read_csv("../../01Data/ValidationDatasets/WeatherStations/PortArthur/GHCNh_USW00012917_2017.psv", sep="|", low_memory=False)
rbrwStation = pd.read_csv("../../01Data/ValidationDatasets/WeatherStations/RobertRWells/GHCNh_USI0000K66R_2017.psv", sep="|", low_memory=False)
sbolStation = pd.read_csv("../../01Data/ValidationDatasets/WeatherStations/SabineOil/GHCNh_USW00000255_2017.psv", sep="|", low_memory=False)
srgtStation = pd.read_csv("../../01Data/ValidationDatasets/WeatherStations/Sargent/GHCNh_USL000SGNT2_2017.psv", sep="|", low_memory=False)
txptStation = pd.read_csv("../../01Data/ValidationDatasets/WeatherStations/TexasPt/GHCNh_USL000TXPT2_2017.psv", sep="|", low_memory=False)
# Out:
# skipping variable: paramId==170 shortName='stl2'
# Traceback (most recent call last):
#   File "C:\Users\rpkamakura\AppData\Local\anaconda3\envs\wrf\Lib\site-packages\cfgrib\dataset.py", line 725, in build_dataset_components
#     dict_merge(variables, coord_vars)
#   File "C:\Users\rpkamakura\AppData\Local\anaconda3\envs\wrf\Lib\site-packages\cfgrib\dataset.py", line 641, in dict_merge
#     raise DatasetBuildError(
# cfgrib.dataset.DatasetBuildError: key present and new value is different: key='depthBelowLandLayer' value=Variable(dimensions=(), data=0.0) new_value=Variable(dimensions=(), data=7.0)
# skipping variable: paramId==183 shortName='stl3'
# Traceback (most recent call last):
#   File "C:\Users\rpkamakura\AppData\Local\anaconda3\envs\wrf\Lib\site-packages\cfgrib\dataset.py", line 725, in build_dataset_components
#     dict_merge(variables, coord_vars)
#   File "C:\Users\rpkamakura\AppData\Local\anaconda3\envs\wrf\Lib\site-packages\cfgrib\dataset.py", line 641, in dict_merge
#     raise DatasetBuildError(
# cfgrib.dataset.DatasetBuildError: key present and new value is different: key='depthBelowLandLayer' value=Variable(dimensions=(), data=0.0) new_value=Variable(dimensions=(), data=28.0)
# skipping variable: paramId==236 shortName='stl4'
# Traceback (most recent call last):
#   File "C:\Users\rpkamakura\AppData\Local\anaconda3\envs\wrf\Lib\site-packages\cfgrib\dataset.py", line 725, in build_dataset_components
#     dict_merge(variables, coord_vars)
#   File "C:\Users\rpkamakura\AppData\Local\anaconda3\envs\wrf\Lib\site-packages\cfgrib\dataset.py", line 641, in dict_merge
#     raise DatasetBuildError(
# cfgrib.dataset.DatasetBuildError: key present and new value is different: key='depthBelowLandLayer' value=Variable(dimensions=(), data=0.0) new_value=Variable(dimensions=(), data=100.0)
# skipping variable: paramId==40 shortName='swvl2'
# Traceback (most recent call last):
#   File "C:\Users\rpkamakura\AppData\Local\anaconda3\envs\wrf\Lib\site-packages\cfgrib\dataset.py", line 725, in build_dataset_components
#     dict_merge(variables, coord_vars)
#   File "C:\Users\rpkamakura\AppData\Local\anaconda3\envs\wrf\Lib\site-packages\cfgrib\dataset.py", line 641, in dict_merge
#     raise DatasetBuildError(
# cfgrib.dataset.DatasetBuildError: key present and new value is different: key='depthBelowLandLayer' value=Variable(dimensions=(), data=0.0) new_value=Variable(dimensions=(), data=7.0)
# skipping variable: paramId==41 shortName='swvl3'
# Traceback (most recent call last):
#   File "C:\Users\rpkamakura\AppData\Local\anaconda3\envs\wrf\Lib\site-packages\cfgrib\dataset.py", line 725, in build_dataset_components
#     dict_merge(variables, coord_vars)
#   File "C:\Users\rpkamakura\AppData\Local\anaconda3\envs\wrf\Lib\site-packages\cfgrib\dataset.py", line 641, in dict_merge
#     raise DatasetBuildError(
# cfgrib.dataset.DatasetBuildError: key present and new value is different: key='depthBelowLandLayer' value=Variable(dimensions=(), data=0.0) new_value=Variable(dimensions=(), data=28.0)
# skipping variable: paramId==42 shortName='swvl4'
# Traceback (most recent call last):
#   File "C:\Users\rpkamakura\AppData\Local\anaconda3\envs\wrf\Lib\site-packages\cfgrib\dataset.py", line 725, in build_dataset_components
#     dict_merge(variables, coord_vars)
#   File "C:\Users\rpkamakura\AppData\Local\anaconda3\envs\wrf\Lib\site-packages\cfgrib\dataset.py", line 641, in dict_merge
#     raise DatasetBuildError(
# cfgrib.dataset.DatasetBuildError: key present and new value is different: key='depthBelowLandLayer' value=Variable(dimensions=(), data=0.0) new_value=Variable(dimensions=(), data=100.0)
# skipping variable: paramId==170 shortName='stl2'
# Traceback (most recent call last):
#   File "C:\Users\rpkamakura\AppData\Local\anaconda3\envs\wrf\Lib\site-packages\cfgrib\dataset.py", line 725, in build_dataset_components
#     dict_merge(variables, coord_vars)
#   File "C:\Users\rpkamakura\AppData\Local\anaconda3\envs\wrf\Lib\site-packages\cfgrib\dataset.py", line 641, in dict_merge
#     raise DatasetBuildError(
# cfgrib.dataset.DatasetBuildError: key present and new value is different: key='depthBelowLandLayer' value=Variable(dimensions=(), data=0.0) new_value=Variable(dimensions=(), data=7.0)
# skipping variable: paramId==183 shortName='stl3'
# Traceback (most recent call last):
#   File "C:\Users\rpkamakura\AppData\Local\anaconda3\envs\wrf\Lib\site-packages\cfgrib\dataset.py", line 725, in build_dataset_components
#     dict_merge(variables, coord_vars)
#   File "C:\Users\rpkamakura\AppData\Local\anaconda3\envs\wrf\Lib\site-packages\cfgrib\dataset.py", line 641, in dict_merge
#     raise DatasetBuildError(
# cfgrib.dataset.DatasetBuildError: key present and new value is different: key='depthBelowLandLayer' value=Variable(dimensions=(), data=0.0) new_value=Variable(dimensions=(), data=28.0)
# skipping variable: paramId==236 shortName='stl4'
# Traceback (most recent call last):
#   File "C:\Users\rpkamakura\AppData\Local\anaconda3\envs\wrf\Lib\site-packages\cfgrib\dataset.py", line 725, in build_dataset_components
#     dict_merge(variables, coord_vars)
#   File "C:\Users\rpkamakura\AppData\Local\anaconda3\envs\wrf\Lib\site-packages\cfgrib\dataset.py", line 641, in dict_merge
#     raise DatasetBuildError(
# cfgrib.dataset.DatasetBuildError: key present and new value is different: key='depthBelowLandLayer' value=Variable(dimensions=(), data=0.0) new_value=Variable(dimensions=(), data=100.0)
# skipping variable: paramId==40 shortName='swvl2'
# Traceback (most recent call last):
#   File "C:\Users\rpkamakura\AppData\Local\anaconda3\envs\wrf\Lib\site-packages\cfgrib\dataset.py", line 725, in build_dataset_components
#     dict_merge(variables, coord_vars)
#   File "C:\Users\rpkamakura\AppData\Local\anaconda3\envs\wrf\Lib\site-packages\cfgrib\dataset.py", line 641, in dict_merge
#     raise DatasetBuildError(
# cfgrib.dataset.DatasetBuildError: key present and new value is different: key='depthBelowLandLayer' value=Variable(dimensions=(), data=0.0) new_value=Variable(dimensions=(), data=7.0)
# skipping variable: paramId==41 shortName='swvl3'
# Traceback (most recent call last):
#   File "C:\Users\rpkamakura\AppData\Local\anaconda3\envs\wrf\Lib\site-packages\cfgrib\dataset.py", line 725, in build_dataset_components
#     dict_merge(variables, coord_vars)
#   File "C:\Users\rpkamakura\AppData\Local\anaconda3\envs\wrf\Lib\site-packages\cfgrib\dataset.py", line 641, in dict_merge
#     raise DatasetBuildError(
# cfgrib.dataset.DatasetBuildError: key present and new value is different: key='depthBelowLandLayer' value=Variable(dimensions=(), data=0.0) new_value=Variable(dimensions=(), data=28.0)
# skipping variable: paramId==42 shortName='swvl4'
# Traceback (most recent call last):
#   File "C:\Users\rpkamakura\AppData\Local\anaconda3\envs\wrf\Lib\site-packages\cfgrib\dataset.py", line 725, in build_dataset_components
#     dict_merge(variables, coord_vars)
#   File "C:\Users\rpkamakura\AppData\Local\anaconda3\envs\wrf\Lib\site-packages\cfgrib\dataset.py", line 641, in dict_merge
#     raise DatasetBuildError(
# cfgrib.dataset.DatasetBuildError: key present and new value is different: key='depthBelowLandLayer' value=Variable(dimensions=(), data=0.0) new_value=Variable(dimensions=(), data=100.0)

# %%
## Get useful station information for later work

#Station locations
lats = [anglStation["LATITUDE"][0], beauStation["LATITUDE"][0], conrStation["LATITUDE"][0], 
        galvStation["LATITUDE"][0], housStation["LATITUDE"][0], clvlStation["LATITUDE"][0], 
        hiolStation["LATITUDE"][0], hseaStation["LATITUDE"][0], hsinStation["LATITUDE"][0], 
        hntsStation["LATITUDE"][0], ptarStation["LATITUDE"][0], rbrwStation["LATITUDE"][0], 
        sbolStation["LATITUDE"][0], srgtStation["LATITUDE"][0], txptStation["LATITUDE"][0]]
lons = [anglStation["LONGITUDE"][0], beauStation["LONGITUDE"][0], conrStation["LONGITUDE"][0], 
        galvStation["LONGITUDE"][0], housStation["LONGITUDE"][0], clvlStation["LONGITUDE"][0], 
        hiolStation["LONGITUDE"][0], hseaStation["LONGITUDE"][0], hsinStation["LONGITUDE"][0], 
        hntsStation["LONGITUDE"][0], ptarStation["LONGITUDE"][0], rbrwStation["LONGITUDE"][0], 
        sbolStation["LONGITUDE"][0], srgtStation["LONGITUDE"][0], txptStation["LONGITUDE"][0]]

## Prep some other variables for comparisons
FocalTimePts = [datetime.fromisoformat("2017-03-23T00:00:00"), datetime.fromisoformat("2017-04-01T00:00:00"), 
                datetime.fromisoformat("2017-04-03T00:00:00")]

#tolerance of difference in lat/lon from target to what we use for the mean. 
#We seem to have values every 0.25 units for each, so these are about half to find the closest
lonTol = 0.13 #unlikely to get an exact match
latTol = 0.13 #unlikely to get an exact match

# %% [markdown]
# Start with the weather stations, going in alphabetical order
#
# * Angleton Lake Jackson
# * Beaumont
# * Conroe
# * Galveston
# * Houston
#
# Newly added:
# * Cleveland
# * High Island Oil
# * Houston Executive Airport
# * Houston Intercontinental Airport
# * Huntsville
# * Port Arthur
# * Robert R Wells
# * Sabine Oil
# * Sargent
# * Texas Point

# %%
##get avg temps
def getAvg(df, qc):

    avg_temps = []
    
    #loop through it
    for t in df.time.values:
    
        focalTime = pd.to_datetime(pd.Timestamp(t))
        # Subset data within the time tolerance
        subset = [
            entry['temperature'] for entry in anglStation
            if abs(datetime.fromisoformat(entry['DATE']) - focalTime) <= tolerance and str(entry['temperature_Quality_Code']) == qc
        ]
    
        # Compute the average temperature if any entries matched
        if subset:
            avg = sum(subset) / len(subset)
        else:
            avg = float('nan')
            
        avg_temps.append(avg)
        
    return avg_temps

# %%
## Comparisons for Angleton Lake Jackson
# Find subset within the tolerance range
anglSubsetMar = era5_sfcMar.t2m.sel(
    latitude=slice(lats[0] + latTol, lats[0] - latTol),
    longitude=slice(lons[0] - lonTol, lons[0] + lonTol),
    time=slice(FocalTimePts[0], FocalTimePts[1])
)

anglSubsetApr = era5_sfcApr.t2m.sel(
    latitude=slice(lats[0] + latTol, lats[0] - latTol),
    longitude=slice(lons[0] - lonTol, lons[0] + lonTol),
    time=slice(FocalTimePts[1], FocalTimePts[2])
)

# %%
#find corresponding temperature values within some tolerance of the era5 times

# Store average temperatures - March
mar_avg_temps = []
tolerance= timedelta(minutes=30)
anglStation = anglStation.to_dict('records')

mar_avg_temps = getAvg(anglSubsetMar, '5')
    
#get the difference between these time points and the closest station values
marDiffs = (anglSubsetMar.mean(dim=['latitude', 'longitude'], skipna=True) - 272.15).values.flatten().flatten() - mar_avg_temps
angl_marDiffs = list(filterfalse(isnan, marDiffs))

# Store average temperatures - April
apr_avg_temps = []
apr_avg_temps = getAvg(anglSubsetApr, '5')
    
#get the difference between these time points and the closest station values
aprDiffs = (anglSubsetApr.mean(dim=['latitude', 'longitude'], skipna=True) - 272.15).values.flatten().flatten() - apr_avg_temps
angl_aprDiffs = list(filterfalse(isnan, aprDiffs))

# %%
#get some summary statistics
angl_avgDiff = statistics.mean([*angl_marDiffs, *angl_aprDiffs])
angl_medDiff = statistics.median([*angl_marDiffs, *angl_aprDiffs])

# %% [markdown]
# Beaumont

# %%
## Comparisons for Beaumont
# Find subset within the tolerance range
beauSubsetMar = era5_sfcMar.t2m.sel(
    latitude=slice(lats[1] + latTol, lats[1] - latTol),
    longitude=slice(lons[1] - lonTol, lons[1] + lonTol),
    time=slice(FocalTimePts[0], FocalTimePts[1])
)

beauSubsetApr = era5_sfcApr.t2m.sel(
    latitude=slice(lats[1] + latTol, lats[1] - latTol),
    longitude=slice(lons[1] - lonTol, lons[1] + lonTol),
    time=slice(FocalTimePts[1], FocalTimePts[2])
)

#find corresponding temperature values within some tolerance of the era5 times

# Store average temperatures - March
mar_avg_temps = []
tolerance= timedelta(minutes=45)
beauStation = beauStation.to_dict('records')

#loop through it
for t in beauSubsetMar.time.values:

    focalTime = pd.to_datetime(pd.Timestamp(t))
    # Subset data within the time tolerance
    subset = [
        entry['temperature'] for entry in beauStation
        if abs(datetime.fromisoformat(entry['DATE']) - focalTime) <= tolerance and str(entry['temperature_Quality_Code']) == '1'
    ]

    #for debugging
    #print(f"Time: {focalTime}, Matched Temps: {subset}")

    
    # Compute the average temperature if any entries matched
    if subset:
        avg = sum(subset) / len(subset)
    else:
        avg = float('nan')
        
    mar_avg_temps.append(avg)
    
#get the difference between these time points and the closest station values
marDiffs = np.array([beauSubsetMar.mean(dim='latitude').values - 272.15]).flatten() - mar_avg_temps
beau_marDiffs = list(filterfalse(isnan, marDiffs))

# Store average temperatures - April
apr_avg_temps = []
tolerance= timedelta(minutes=30)

#loop through it
for t in beauSubsetApr.time.values:

    focalTime = pd.to_datetime(pd.Timestamp(t))
    # Subset data within the time tolerance
    subset = [
        entry['temperature'] for entry in beauStation
        if abs(datetime.fromisoformat(entry['DATE']) - focalTime) <= tolerance and str(entry['temperature_Quality_Code']) == '1'
    ]

    # Compute the average temperature if any entries matched
    if subset:
        avg = sum(subset) / len(subset)
    else:
        avg = float('nan')
        
    apr_avg_temps.append(avg)
    
#get the difference between these time points and the closest station values
aprDiffs = np.array([beauSubsetApr.mean(dim='latitude').values - 272.15]).flatten() - apr_avg_temps
beau_aprDiffs = list(filterfalse(isnan, aprDiffs))

# %%
#get some summary statistics
beau_avgDiff = statistics.mean([*marDiffs.tolist(), *aprDiffs.tolist()])
beau_medDiff = statistics.median([*marDiffs.tolist(), *aprDiffs.tolist()])

# %% [markdown]
# Conroe

# %%
## Comparisons for Conroe
# Find subset within the tolerance range
conrSubsetMar = era5_sfcMar.t2m.sel(
    latitude=slice(lats[2] + latTol, lats[2] - latTol),
    longitude=slice(lons[2] - lonTol, lons[2] + lonTol),
    time=slice(FocalTimePts[0], FocalTimePts[1])
)

conrSubsetApr = era5_sfcApr.t2m.sel(
    latitude=slice(lats[2] + latTol, lats[2] - latTol),
    longitude=slice(lons[2] - lonTol, lons[2] + lonTol),
    time=slice(FocalTimePts[1], FocalTimePts[2])
)

#find corresponding temperature values within some tolerance of the era5 times

# Store average temperatures - March
mar_avg_temps = []
tolerance= timedelta(minutes=30)
conrStation = conrStation.to_dict('records')

#loop through it
for t in conrSubsetMar.time.values:

    focalTime = pd.to_datetime(pd.Timestamp(t))
    # Subset data within the time tolerance
    subset = [
        entry['temperature'] for entry in conrStation
        if abs(datetime.fromisoformat(entry['DATE']) - focalTime) <= tolerance and str(entry['temperature_Quality_Code']) == '5.0'
    ]

    # Compute the average temperature if any entries matched
    if subset:
        avg = sum(subset) / len(subset)
    else:
        avg = float('nan')
        
    mar_avg_temps.append(avg)
    
#get the difference between these time points and the closest station values
marDiffs = np.array([conrSubsetMar.values - 272.15]).flatten() - mar_avg_temps
conr_marDiffs = list(filterfalse(isnan, marDiffs))

# Store average temperatures - April
apr_avg_temps = []
tolerance= timedelta(minutes=30)

#loop through it
for t in conrSubsetApr.time.values:

    focalTime = pd.to_datetime(pd.Timestamp(t))
    # Subset data within the time tolerance
    subset = [
        entry['temperature'] for entry in conrStation
        if abs(datetime.fromisoformat(entry['DATE']) - focalTime) <= tolerance and str(entry['temperature_Quality_Code']) == '5.0'
    ]

    # Compute the average temperature if any entries matched
    if subset:
        avg = sum(subset) / len(subset)
    else:
        avg = float('nan')
        
    apr_avg_temps.append(avg)
    

#get the difference between these time points and the closest station values
aprDiffs = np.array([conrSubsetApr.values - 272.15]).flatten() - apr_avg_temps
conr_aprDiffs = list(filterfalse(isnan, aprDiffs))

# %%
#get some summary statistics
conr_avgDiff = statistics.mean([*conr_marDiffs, *conr_aprDiffs])
conr_medDiff = statistics.median([*conr_marDiffs, *conr_aprDiffs])

# %% [markdown]
# Galveston

# %%
## Comparisons for Galveston
# Find subset within the tolerance range
galvSubsetMar = era5_sfcMar.t2m.sel(
    latitude=slice(lats[2] + latTol, lats[2] - latTol),
    longitude=slice(lons[2] - lonTol, lons[2] + lonTol),
    time=slice(FocalTimePts[0], FocalTimePts[1])
)

galvSubsetApr = era5_sfcApr.t2m.sel(
    latitude=slice(lats[2] + latTol, lats[2] - latTol),
    longitude=slice(lons[2] - lonTol, lons[2] + lonTol),
    time=slice(FocalTimePts[1], FocalTimePts[2])
)

#find corresponding temperature values within some tolerance of the era5 times

# Store average temperatures - March
mar_avg_temps = []
tolerance= timedelta(minutes=30)
galvStation = galvStation.to_dict('records')

#loop through it
for t in galvSubsetMar.time.values:

    focalTime = pd.to_datetime(pd.Timestamp(t))
    # Subset data within the time tolerance
    subset = [
        entry['temperature'] for entry in galvStation
        if abs(datetime.fromisoformat(entry['DATE']) - focalTime) <= tolerance and str(entry['temperature_Quality_Code']) == '5.0'
    ]

    # Compute the average temperature if any entries matched
    if subset:
        avg = sum(subset) / len(subset)
    else:
        avg = float('nan')
        
    mar_avg_temps.append(avg)
    
#get the difference between these time points and the closest station values
galv_marDiffs = np.array([galvSubsetMar.mean(dim='latitude').values - 272.15]).flatten() - mar_avg_temps
galv_marDiffs_nn = list(filterfalse(isnan, galv_marDiffs))

# Store average temperatures - April
apr_avg_temps = []
tolerance= timedelta(minutes=30)

#loop through it
for t in galvSubsetApr.time.values:

    focalTime = pd.to_datetime(pd.Timestamp(t))
    # Subset data within the time tolerance
    subset = [
        entry['temperature'] for entry in galvStation
        if abs(datetime.fromisoformat(entry['DATE']) - focalTime) <= tolerance and str(entry['temperature_Quality_Code']) == '5.0'
    ]

    # Compute the average temperature if any entries matched
    if subset:
        avg = sum(subset) / len(subset)
    else:
        avg = float('nan')
        
    apr_avg_temps.append(avg)
    
#get the difference between these time points and the closest station values
galv_aprDiffs = np.array([galvSubsetApr.mean(dim='latitude').values - 272.15]).flatten() - apr_avg_temps
galv_aprDiffs_nn = list(filterfalse(isnan, galv_aprDiffs))

# %%
#get some summary statistics
galv_avgDiff = statistics.mean([*galv_marDiffs_nn, *galv_aprDiffs_nn])
galv_medDiff = statistics.median([*galv_marDiffs_nn, *galv_aprDiffs_nn])

# %% [markdown]
# Houston

# %%
## Comparisons for Houston
# Find subset within the tolerance range
housSubsetMar = era5_sfcMar.t2m.sel(
    latitude=slice(lats[2] + latTol, lats[2] - latTol),
    longitude=slice(lons[2] - lonTol, lons[2] + lonTol),
    time=slice(FocalTimePts[0], FocalTimePts[1])
)

housSubsetApr = era5_sfcApr.t2m.sel(
    latitude=slice(lats[2] + latTol, lats[2] - latTol),
    longitude=slice(lons[2] - lonTol, lons[2] + lonTol),
    time=slice(FocalTimePts[1], FocalTimePts[2])
)

#find corresponding temperature values within some tolerance of the era5 times

# Store average temperatures - March
mar_avg_temps = []
tolerance= timedelta(minutes=30)
housStation = housStation.to_dict('records')

#loop through it
for t in housSubsetMar.time.values:

    focalTime = pd.to_datetime(pd.Timestamp(t))
    # Subset data within the time tolerance
    subset = [
        entry['temperature'] for entry in housStation
        if abs(datetime.fromisoformat(entry['DATE']) - focalTime) <= tolerance and str(entry['temperature_Quality_Code']) == '5.0'
    ]

    # Compute the average temperature if any entries matched
    if subset:
        avg = sum(subset) / len(subset)
    else:
        avg = float('nan')
        
    mar_avg_temps.append(avg)
    
#get the difference between these time points and the closest station values
marDiffs = np.array([housSubsetMar.mean(dim='latitude').values - 272.15]).flatten() - mar_avg_temps
hous_marDiffs = list(filterfalse(isnan, marDiffs))

# Store average temperatures - April
apr_avg_temps = []
tolerance= timedelta(minutes=30)

#loop through it
for t in housSubsetApr.time.values:

    focalTime = pd.to_datetime(pd.Timestamp(t))
    # Subset data within the time tolerance
    subset = [
        entry['temperature'] for entry in housStation
        if abs(datetime.fromisoformat(entry['DATE']) - focalTime) <= tolerance and str(entry['temperature_Quality_Code']) == '5.0'
    ]

    # Compute the average temperature if any entries matched
    if subset:
        avg = sum(subset) / len(subset)
    else:
        avg = float('nan')
        
    apr_avg_temps.append(avg)
    
#get the difference between these time points and the closest station values
aprDiffs = np.array([housSubsetApr.mean(dim='latitude').values - 272.15]).flatten() - apr_avg_temps
hous_aprDiffs = list(filterfalse(isnan, aprDiffs))

# %%
#get some summary statistics
hous_avgDiff = statistics.mean([*hous_marDiffs, *hous_aprDiffs])
hous_medDiff = statistics.median([*hous_marDiffs, *hous_aprDiffs])

# %%
## Comparisons for Cleveland
# Find subset within the tolerance range
clvlSubsetMar = era5_sfcMar.t2m.sel(
    latitude=slice(lats[2] + latTol, lats[2] - latTol),
    longitude=slice(lons[2] - lonTol, lons[2] + lonTol),
    time=slice(FocalTimePts[0], FocalTimePts[1])
)

clvlSubsetApr = era5_sfcApr.t2m.sel(
    latitude=slice(lats[2] + latTol, lats[2] - latTol),
    longitude=slice(lons[2] - lonTol, lons[2] + lonTol),
    time=slice(FocalTimePts[1], FocalTimePts[2])
)

#find corresponding temperature values within some tolerance of the era5 times

# Store average temperatures - March
mar_avg_temps = []
tolerance= timedelta(minutes=30)
clvlStation = clvlStation.to_dict('records')

#loop through it
for t in clvlSubsetMar.time.values:

    focalTime = pd.to_datetime(pd.Timestamp(t))
    # Subset data within the time tolerance
    subset = [
        entry['temperature'] for entry in clvlStation
        if abs(datetime.fromisoformat(entry['DATE']) - focalTime) <= tolerance and str(entry['temperature_Quality_Code']) == '5.0'
    ]

    # Compute the average temperature if any entries matched
    if subset:
        avg = sum(subset) / len(subset)
    else:
        avg = float('nan')
        
    mar_avg_temps.append(avg)
    
#get the difference between these time points and the closest station values
marDiffs = np.array([clvlSubsetMar.mean(dim='latitude').values - 272.15]).flatten() - mar_avg_temps
clvl_marDiffs = list(filterfalse(isnan, marDiffs))

# Store average temperatures - April
apr_avg_temps = []
tolerance= timedelta(minutes=30)

#loop through it
for t in clvlSubsetApr.time.values:

    focalTime = pd.to_datetime(pd.Timestamp(t))
    # Subset data within the time tolerance
    subset = [
        entry['temperature'] for entry in clvlStation
        if abs(datetime.fromisoformat(entry['DATE']) - focalTime) <= tolerance and str(entry['temperature_Quality_Code']) == '5.0'
    ]

    # Compute the average temperature if any entries matched
    if subset:
        avg = sum(subset) / len(subset)
    else:
        avg = float('nan')
        
    apr_avg_temps.append(avg)
    
#get the difference between these time points and the closest station values
aprDiffs = np.array([clvlSubsetApr.mean(dim='latitude').values - 272.15]).flatten() - apr_avg_temps
clvl_aprDiffs = list(filterfalse(isnan, aprDiffs))

# %%
#get some summary statistics
clvl_avgDiff = statistics.mean([*clvl_marDiffs, *clvl_aprDiffs])
clvl_medDiff = statistics.median([*clvl_marDiffs, *clvl_aprDiffs])

# %%
## Comparisons for High Island Oil
# Find subset within the tolerance range
hiolSubsetMar = era5_sfcMar.t2m.sel(
    latitude=slice(lats[2] + latTol, lats[2] - latTol),
    longitude=slice(lons[2] - lonTol, lons[2] + lonTol),
    time=slice(FocalTimePts[0], FocalTimePts[1])
)

hiolSubsetApr = era5_sfcApr.t2m.sel(
    latitude=slice(lats[2] + latTol, lats[2] - latTol),
    longitude=slice(lons[2] - lonTol, lons[2] + lonTol),
    time=slice(FocalTimePts[1], FocalTimePts[2])
)

#find corresponding temperature values within some tolerance of the era5 times

# Store average temperatures - March
mar_avg_temps = []
tolerance= timedelta(minutes=30)
hiolStation = hiolStation.to_dict('records')

#loop through it
for t in hiolSubsetMar.time.values:

    focalTime = pd.to_datetime(pd.Timestamp(t))
    # Subset data within the time tolerance
    subset = [
        entry['temperature'] for entry in hiolStation
        if abs(datetime.fromisoformat(entry['DATE']) - focalTime) <= tolerance and str(entry['temperature_Quality_Code']) == '5.0'
    ]

    # Compute the average temperature if any entries matched
    if subset:
        avg = sum(subset) / len(subset)
    else:
        avg = float('nan')
        
    mar_avg_temps.append(avg)
    
#get the difference between these time points and the closest station values
marDiffs = np.array([hiolSubsetMar.mean(dim='latitude').values - 272.15]).flatten() - mar_avg_temps
hiol_marDiffs = list(filterfalse(isnan, marDiffs))

# Store average temperatures - April
apr_avg_temps = []
tolerance= timedelta(minutes=30)

#loop through it
for t in hiolSubsetApr.time.values:

    focalTime = pd.to_datetime(pd.Timestamp(t))
    # Subset data within the time tolerance
    subset = [
        entry['temperature'] for entry in hiolStation
        if abs(datetime.fromisoformat(entry['DATE']) - focalTime) <= tolerance and str(entry['temperature_Quality_Code']) == '5.0'
    ]

    # Compute the average temperature if any entries matched
    if subset:
        avg = sum(subset) / len(subset)
    else:
        avg = float('nan')
        
    apr_avg_temps.append(avg)
    
#get the difference between these time points and the closest station values
aprDiffs = np.array([hiolSubsetApr.mean(dim='latitude').values - 272.15]).flatten() - apr_avg_temps
hiol_aprDiffs = list(filterfalse(isnan, aprDiffs))

# %%
#get some summary statistics
hiol_avgDiff = statistics.mean([*hiol_marDiffs, *hiol_aprDiffs])
hiol_medDiff = statistics.median([*hiol_marDiffs, *hiol_aprDiffs])

# %%
## Comparisons for Houston Executive Airport
# Find subset within the tolerance range
hseaSubsetMar = era5_sfcMar.t2m.sel(
    latitude=slice(lats[2] + latTol, lats[2] - latTol),
    longitude=slice(lons[2] - lonTol, lons[2] + lonTol),
    time=slice(FocalTimePts[0], FocalTimePts[1])
)

hseaSubsetApr = era5_sfcApr.t2m.sel(
    latitude=slice(lats[2] + latTol, lats[2] - latTol),
    longitude=slice(lons[2] - lonTol, lons[2] + lonTol),
    time=slice(FocalTimePts[1], FocalTimePts[2])
)

#find corresponding temperature values within some tolerance of the era5 times

# Store average temperatures - March
mar_avg_temps = []
tolerance= timedelta(minutes=30)
hseaStation = hseaStation.to_dict('records')

#loop through it
for t in hseaSubsetMar.time.values:

    focalTime = pd.to_datetime(pd.Timestamp(t))
    # Subset data within the time tolerance
    subset = [
        entry['temperature'] for entry in hseaStation
        if abs(datetime.fromisoformat(entry['DATE']) - focalTime) <= tolerance and str(entry['temperature_Quality_Code']) == '5.0'
    ]

    # Compute the average temperature if any entries matched
    if subset:
        avg = sum(subset) / len(subset)
    else:
        avg = float('nan')
        
    mar_avg_temps.append(avg)
    
#get the difference between these time points and the closest station values
marDiffs = np.array([hseaSubsetMar.mean(dim='latitude').values - 272.15]).flatten() - mar_avg_temps
hsea_marDiffs = list(filterfalse(isnan, marDiffs))

# Store average temperatures - April
apr_avg_temps = []
tolerance= timedelta(minutes=30)

#loop through it
for t in hseaSubsetApr.time.values:

    focalTime = pd.to_datetime(pd.Timestamp(t))
    # Subset data within the time tolerance
    subset = [
        entry['temperature'] for entry in hseaStation
        if abs(datetime.fromisoformat(entry['DATE']) - focalTime) <= tolerance and str(entry['temperature_Quality_Code']) == '5.0'
    ]

    # Compute the average temperature if any entries matched
    if subset:
        avg = sum(subset) / len(subset)
    else:
        avg = float('nan')
        
    apr_avg_temps.append(avg)
    
#get the difference between these time points and the closest station values
aprDiffs = np.array([hseaSubsetApr.mean(dim='latitude').values - 272.15]).flatten() - apr_avg_temps
hsea_aprDiffs = list(filterfalse(isnan, aprDiffs))

# %%
#get some summary statistics
hsea_avgDiff = statistics.mean([*hsea_marDiffs, *hsea_aprDiffs])
hsea_medDiff = statistics.median([*hsea_marDiffs, *hsea_aprDiffs])

# %%
## Comparisons for Houston Intercontinental Airport
# Find subset within the tolerance range
hsinSubsetMar = era5_sfcMar.t2m.sel(
    latitude=slice(lats[2] + latTol, lats[2] - latTol),
    longitude=slice(lons[2] - lonTol, lons[2] + lonTol),
    time=slice(FocalTimePts[0], FocalTimePts[1])
)

hsinSubsetApr = era5_sfcApr.t2m.sel(
    latitude=slice(lats[2] + latTol, lats[2] - latTol),
    longitude=slice(lons[2] - lonTol, lons[2] + lonTol),
    time=slice(FocalTimePts[1], FocalTimePts[2])
)

#find corresponding temperature values within some tolerance of the era5 times

# Store average temperatures - March
mar_avg_temps = []
tolerance= timedelta(minutes=30)
hsinStation = hsinStation.to_dict('records')

#loop through it
for t in hsinSubsetMar.time.values:

    focalTime = pd.to_datetime(pd.Timestamp(t))
    # Subset data within the time tolerance
    subset = [
        entry['temperature'] for entry in hsinStation
        if abs(datetime.fromisoformat(entry['DATE']) - focalTime) <= tolerance and str(entry['temperature_Quality_Code']) == '5.0'
    ]

    # Compute the average temperature if any entries matched
    if subset:
        avg = sum(subset) / len(subset)
    else:
        avg = float('nan')
        
    mar_avg_temps.append(avg)
    
#get the difference between these time points and the closest station values
marDiffs = np.array([hsinSubsetMar.mean(dim='latitude').values - 272.15]).flatten() - mar_avg_temps
hsin_marDiffs = list(filterfalse(isnan, marDiffs))

# Store average temperatures - April
apr_avg_temps = []
tolerance= timedelta(minutes=30)

#loop through it
for t in hsinSubsetApr.time.values:

    focalTime = pd.to_datetime(pd.Timestamp(t))
    # Subset data within the time tolerance
    subset = [
        entry['temperature'] for entry in hsinStation
        if abs(datetime.fromisoformat(entry['DATE']) - focalTime) <= tolerance and str(entry['temperature_Quality_Code']) == '5.0'
    ]

    # Compute the average temperature if any entries matched
    if subset:
        avg = sum(subset) / len(subset)
    else:
        avg = float('nan')
        
    apr_avg_temps.append(avg)
    
#get the difference between these time points and the closest station values
aprDiffs = np.array([hsinSubsetApr.mean(dim='latitude').values - 272.15]).flatten() - apr_avg_temps
hsin_aprDiffs = list(filterfalse(isnan, aprDiffs))

# %%
#get some summary statistics
hsin_avgDiff = statistics.mean([*hsin_marDiffs, *hsin_aprDiffs])
hsin_medDiff = statistics.median([*hsin_marDiffs, *hsin_aprDiffs])

# %%
## Comparisons for Huntsville
# Find subset within the tolerance range
hntsSubsetMar = era5_sfcMar.t2m.sel(
    latitude=slice(lats[2] + latTol, lats[2] - latTol),
    longitude=slice(lons[2] - lonTol, lons[2] + lonTol),
    time=slice(FocalTimePts[0], FocalTimePts[1])
)

hntsSubsetApr = era5_sfcApr.t2m.sel(
    latitude=slice(lats[2] + latTol, lats[2] - latTol),
    longitude=slice(lons[2] - lonTol, lons[2] + lonTol),
    time=slice(FocalTimePts[1], FocalTimePts[2])
)

#find corresponding temperature values within some tolerance of the era5 times

# Store average temperatures - March
mar_avg_temps = []
tolerance= timedelta(minutes=30)
hntsStation = hntsStation.to_dict('records')

#loop through it
for t in hntsSubsetMar.time.values:

    focalTime = pd.to_datetime(pd.Timestamp(t))
    # Subset data within the time tolerance
    subset = [
        entry['temperature'] for entry in hntsStation
        if abs(datetime.fromisoformat(entry['DATE']) - focalTime) <= tolerance and str(entry['temperature_Quality_Code']) == '5.0'
    ]

    # Compute the average temperature if any entries matched
    if subset:
        avg = sum(subset) / len(subset)
    else:
        avg = float('nan')
        
    mar_avg_temps.append(avg)
    
#get the difference between these time points and the closest station values
marDiffs = np.array([hntsSubsetMar.mean(dim='latitude').values - 272.15]).flatten() - mar_avg_temps
hnts_marDiffs = list(filterfalse(isnan, marDiffs))

# Store average temperatures - April
apr_avg_temps = []
tolerance= timedelta(minutes=30)

#loop through it
for t in hntsSubsetApr.time.values:

    focalTime = pd.to_datetime(pd.Timestamp(t))
    # Subset data within the time tolerance
    subset = [
        entry['temperature'] for entry in hntsStation
        if abs(datetime.fromisoformat(entry['DATE']) - focalTime) <= tolerance and str(entry['temperature_Quality_Code']) == '5.0'
    ]

    # Compute the average temperature if any entries matched
    if subset:
        avg = sum(subset) / len(subset)
    else:
        avg = float('nan')
        
    apr_avg_temps.append(avg)
    
#get the difference between these time points and the closest station values
aprDiffs = np.array([hntsSubsetApr.mean(dim='latitude').values - 272.15]).flatten() - apr_avg_temps
hnts_aprDiffs = list(filterfalse(isnan, aprDiffs))

# %%
#get some summary statistics
hnts_avgDiff = statistics.mean([*hnts_marDiffs, *hnts_aprDiffs])
hnts_medDiff = statistics.median([*hnts_marDiffs, *hnts_aprDiffs])

# %%
## Comparisons for Port Arthur
# Find subset within the tolerance range
ptarSubsetMar = era5_sfcMar.t2m.sel(
    latitude=slice(lats[2] + latTol, lats[2] - latTol),
    longitude=slice(lons[2] - lonTol, lons[2] + lonTol),
    time=slice(FocalTimePts[0], FocalTimePts[1])
)

ptarSubsetApr = era5_sfcApr.t2m.sel(
    latitude=slice(lats[2] + latTol, lats[2] - latTol),
    longitude=slice(lons[2] - lonTol, lons[2] + lonTol),
    time=slice(FocalTimePts[1], FocalTimePts[2])
)

#find corresponding temperature values within some tolerance of the era5 times

# Store average temperatures - March
mar_avg_temps = []
tolerance= timedelta(minutes=30)
ptarStation = ptarStation.to_dict('records')

#loop through it
for t in ptarSubsetMar.time.values:

    focalTime = pd.to_datetime(pd.Timestamp(t))
    # Subset data within the time tolerance
    subset = [
        entry['temperature'] for entry in ptarStation
        if abs(datetime.fromisoformat(entry['DATE']) - focalTime) <= tolerance and str(entry['temperature_Quality_Code']) == '5.0'
    ]

    # Compute the average temperature if any entries matched
    if subset:
        avg = sum(subset) / len(subset)
    else:
        avg = float('nan')
        
    mar_avg_temps.append(avg)
    
#get the difference between these time points and the closest station values
marDiffs = np.array([ptarSubsetMar.mean(dim='latitude').values - 272.15]).flatten() - mar_avg_temps
ptar_marDiffs = list(filterfalse(isnan, marDiffs))

# Store average temperatures - April
apr_avg_temps = []
tolerance= timedelta(minutes=30)

#loop through it
for t in ptarSubsetApr.time.values:

    focalTime = pd.to_datetime(pd.Timestamp(t))
    # Subset data within the time tolerance
    subset = [
        entry['temperature'] for entry in ptarStation
        if abs(datetime.fromisoformat(entry['DATE']) - focalTime) <= tolerance and str(entry['temperature_Quality_Code']) == '5.0'
    ]

    # Compute the average temperature if any entries matched
    if subset:
        avg = sum(subset) / len(subset)
    else:
        avg = float('nan')
        
    apr_avg_temps.append(avg)
    
#get the difference between these time points and the closest station values
aprDiffs = np.array([ptarSubsetApr.mean(dim='latitude').values - 272.15]).flatten() - apr_avg_temps
ptar_aprDiffs = list(filterfalse(isnan, aprDiffs))

# %%
#get some summary statistics
ptar_avgDiff = statistics.mean([*ptar_marDiffs, *ptar_aprDiffs])
ptar_medDiff = statistics.median([*ptar_marDiffs, *ptar_aprDiffs])

# %%
## Comparisons for Robert R Wells
# Find subset within the tolerance range
rbrwSubsetMar = era5_sfcMar.t2m.sel(
    latitude=slice(lats[2] + latTol, lats[2] - latTol),
    longitude=slice(lons[2] - lonTol, lons[2] + lonTol),
    time=slice(FocalTimePts[0], FocalTimePts[1])
)

rbrwSubsetApr = era5_sfcApr.t2m.sel(
    latitude=slice(lats[2] + latTol, lats[2] - latTol),
    longitude=slice(lons[2] - lonTol, lons[2] + lonTol),
    time=slice(FocalTimePts[1], FocalTimePts[2])
)

#find corresponding temperature values within some tolerance of the era5 times

# Store average temperatures - March
mar_avg_temps = []
tolerance= timedelta(minutes=30)
rbrwStation = rbrwStation.to_dict('records')

#loop through it
for t in rbrwSubsetMar.time.values:

    focalTime = pd.to_datetime(pd.Timestamp(t))
    # Subset data within the time tolerance
    subset = [
        entry['temperature'] for entry in rbrwStation
        if abs(datetime.fromisoformat(entry['DATE']) - focalTime) <= tolerance and str(entry['temperature_Quality_Code']) == '5.0'
    ]

    # Compute the average temperature if any entries matched
    if subset:
        avg = sum(subset) / len(subset)
    else:
        avg = float('nan')
        
    mar_avg_temps.append(avg)
    
#get the difference between these time points and the closest station values
marDiffs = np.array([rbrwSubsetMar.mean(dim='latitude').values - 272.15]).flatten() - mar_avg_temps
rbrw_marDiffs = list(filterfalse(isnan, marDiffs))

# Store average temperatures - April
apr_avg_temps = []
tolerance= timedelta(minutes=30)

#loop through it
for t in rbrwSubsetApr.time.values:

    focalTime = pd.to_datetime(pd.Timestamp(t))
    # Subset data within the time tolerance
    subset = [
        entry['temperature'] for entry in rbrwStation
        if abs(datetime.fromisoformat(entry['DATE']) - focalTime) <= tolerance and str(entry['temperature_Quality_Code']) == '5.0'
    ]

    # Compute the average temperature if any entries matched
    if subset:
        avg = sum(subset) / len(subset)
    else:
        avg = float('nan')
        
    apr_avg_temps.append(avg)
    
#get the difference between these time points and the closest station values
aprDiffs = np.array([rbrwSubsetApr.mean(dim='latitude').values - 272.15]).flatten() - apr_avg_temps
rbrw_aprDiffs = list(filterfalse(isnan, aprDiffs))

# %%
#get some summary statistics
rbrw_avgDiff = statistics.mean([*rbrw_marDiffs, *rbrw_aprDiffs])
rbrw_medDiff = statistics.median([*rbrw_marDiffs, *rbrw_aprDiffs])

# %%
## Comparisons for Sabine Oil
# Find subset within the tolerance range
sbolSubsetMar = era5_sfcMar.t2m.sel(
    latitude=slice(lats[2] + latTol, lats[2] - latTol),
    longitude=slice(lons[2] - lonTol, lons[2] + lonTol),
    time=slice(FocalTimePts[0], FocalTimePts[1])
)

sbolSubsetApr = era5_sfcApr.t2m.sel(
    latitude=slice(lats[2] + latTol, lats[2] - latTol),
    longitude=slice(lons[2] - lonTol, lons[2] + lonTol),
    time=slice(FocalTimePts[1], FocalTimePts[2])
)

#find corresponding temperature values within some tolerance of the era5 times

# Store average temperatures - March
mar_avg_temps = []
tolerance= timedelta(minutes=30)
sbolStation = sbolStation.to_dict('records')

#loop through it
for t in sbolSubsetMar.time.values:

    focalTime = pd.to_datetime(pd.Timestamp(t))
    # Subset data within the time tolerance
    subset = [
        entry['temperature'] for entry in sbolStation
        if abs(datetime.fromisoformat(entry['DATE']) - focalTime) <= tolerance and str(entry['temperature_Quality_Code']) == '5.0'
    ]

    # Compute the average temperature if any entries matched
    if subset:
        avg = sum(subset) / len(subset)
    else:
        avg = float('nan')
        
    mar_avg_temps.append(avg)
    
#get the difference between these time points and the closest station values
marDiffs = np.array([sbolSubsetMar.mean(dim='latitude').values - 272.15]).flatten() - mar_avg_temps
sbol_marDiffs = list(filterfalse(isnan, marDiffs))

# Store average temperatures - April
apr_avg_temps = []
tolerance= timedelta(minutes=30)

#loop through it
for t in sbolSubsetApr.time.values:

    focalTime = pd.to_datetime(pd.Timestamp(t))
    # Subset data within the time tolerance
    subset = [
        entry['temperature'] for entry in sbolStation
        if abs(datetime.fromisoformat(entry['DATE']) - focalTime) <= tolerance and str(entry['temperature_Quality_Code']) == '5.0'
    ]

    # Compute the average temperature if any entries matched
    if subset:
        avg = sum(subset) / len(subset)
    else:
        avg = float('nan')
        
    apr_avg_temps.append(avg)
    
#get the difference between these time points and the closest station values
aprDiffs = np.array([sbolSubsetApr.mean(dim='latitude').values - 272.15]).flatten() - apr_avg_temps
sbol_aprDiffs = list(filterfalse(isnan, aprDiffs))

# %%
#get some summary statistics
sbol_avgDiff = statistics.mean([*sbol_marDiffs, *sbol_aprDiffs])
sbol_medDiff = statistics.median([*sbol_marDiffs, *sbol_aprDiffs])

# %%
## Comparisons for Sargent
# Find subset within the tolerance range
srgtSubsetMar = era5_sfcMar.t2m.sel(
    latitude=slice(lats[2] + latTol, lats[2] - latTol),
    longitude=slice(lons[2] - lonTol, lons[2] + lonTol),
    time=slice(FocalTimePts[0], FocalTimePts[1])
)

srgtSubsetApr = era5_sfcApr.t2m.sel(
    latitude=slice(lats[2] + latTol, lats[2] - latTol),
    longitude=slice(lons[2] - lonTol, lons[2] + lonTol),
    time=slice(FocalTimePts[1], FocalTimePts[2])
)

#find corresponding temperature values within some tolerance of the era5 times

# Store average temperatures - March
mar_avg_temps = []
tolerance= timedelta(minutes=30)
srgtStation = srgtStation.to_dict('records')

#loop through it
for t in srgtSubsetMar.time.values:

    focalTime = pd.to_datetime(pd.Timestamp(t))
    # Subset data within the time tolerance
    subset = [
        entry['temperature'] for entry in srgtStation
        if abs(datetime.fromisoformat(entry['DATE']) - focalTime) <= tolerance and str(entry['temperature_Quality_Code']) == '5.0'
    ]

    # Compute the average temperature if any entries matched
    if subset:
        avg = sum(subset) / len(subset)
    else:
        avg = float('nan')
        
    mar_avg_temps.append(avg)
    
#get the difference between these time points and the closest station values
marDiffs = np.array([srgtSubsetMar.mean(dim='latitude').values - 272.15]).flatten() - mar_avg_temps
srgt_marDiffs = list(filterfalse(isnan, marDiffs))

# Store average temperatures - April
apr_avg_temps = []
tolerance= timedelta(minutes=30)

#loop through it
for t in srgtSubsetApr.time.values:

    focalTime = pd.to_datetime(pd.Timestamp(t))
    # Subset data within the time tolerance
    subset = [
        entry['temperature'] for entry in srgtStation
        if abs(datetime.fromisoformat(entry['DATE']) - focalTime) <= tolerance and str(entry['temperature_Quality_Code']) == '5.0'
    ]

    # Compute the average temperature if any entries matched
    if subset:
        avg = sum(subset) / len(subset)
    else:
        avg = float('nan')
        
    apr_avg_temps.append(avg)
    
#get the difference between these time points and the closest station values
aprDiffs = np.array([srgtSubsetApr.mean(dim='latitude').values - 272.15]).flatten() - apr_avg_temps
srgt_aprDiffs = list(filterfalse(isnan, aprDiffs))

# %%
#get some summary statistics
srgt_avgDiff = statistics.mean([*srgt_marDiffs, *srgt_aprDiffs])
srgt_medDiff = statistics.median([*srgt_marDiffs, *srgt_aprDiffs])

# %%
## Comparisons for Texas Point
# Find subset within the tolerance range
txptSubsetMar = era5_sfcMar.t2m.sel(
    latitude=slice(lats[2] + latTol, lats[2] - latTol),
    longitude=slice(lons[2] - lonTol, lons[2] + lonTol),
    time=slice(FocalTimePts[0], FocalTimePts[1])
)

txptSubsetApr = era5_sfcApr.t2m.sel(
    latitude=slice(lats[2] + latTol, lats[2] - latTol),
    longitude=slice(lons[2] - lonTol, lons[2] + lonTol),
    time=slice(FocalTimePts[1], FocalTimePts[2])
)

#find corresponding temperature values within some tolerance of the era5 times

# Store average temperatures - March
mar_avg_temps = []
tolerance= timedelta(minutes=30)
txptStation = txptStation.to_dict('records')

#loop through it
for t in txptSubsetMar.time.values:

    focalTime = pd.to_datetime(pd.Timestamp(t))
    # Subset data within the time tolerance
    subset = [
        entry['temperature'] for entry in txptStation
        if abs(datetime.fromisoformat(entry['DATE']) - focalTime) <= tolerance and str(entry['temperature_Quality_Code']) == '5.0'
    ]

    # Compute the average temperature if any entries matched
    if subset:
        avg = sum(subset) / len(subset)
    else:
        avg = float('nan')
        
    mar_avg_temps.append(avg)
    
#get the difference between these time points and the closest station values
marDiffs = np.array([txptSubsetMar.mean(dim='latitude').values - 272.15]).flatten() - mar_avg_temps
txpt_marDiffs = list(filterfalse(isnan, marDiffs))

# Store average temperatures - April
apr_avg_temps = []
tolerance= timedelta(minutes=30)

#loop through it
for t in txptSubsetApr.time.values:

    focalTime = pd.to_datetime(pd.Timestamp(t))
    # Subset data within the time tolerance
    subset = [
        entry['temperature'] for entry in txptStation
        if abs(datetime.fromisoformat(entry['DATE']) - focalTime) <= tolerance and str(entry['temperature_Quality_Code']) == '5.0'
    ]

    # Compute the average temperature if any entries matched
    if subset:
        avg = sum(subset) / len(subset)
    else:
        avg = float('nan')
        
    apr_avg_temps.append(avg)
    
#get the difference between these time points and the closest station values
aprDiffs = np.array([txptSubsetApr.mean(dim='latitude').values - 272.15]).flatten() - apr_avg_temps
txpt_aprDiffs = list(filterfalse(isnan, aprDiffs))

# %%
#get some summary statistics
txpt_avgDiff = statistics.mean([*txpt_marDiffs, *txpt_aprDiffs])
txpt_medDiff = statistics.median([*txpt_marDiffs, *txpt_aprDiffs])

# %%
means = [angl_avgDiff, beau_avgDiff, conr_avgDiff, galv_avgDiff, hous_avgDiff, clvl_avgDiff, 
         hiol_avgDiff, hsea_avgDiff, hsin_avgDiff, hnts_avgDiff, ptar_avgDiff, rbrw_avgDiff, 
         sbol_avgDiff, srgt_avgDiff, txpt_avgDiff]
medians = [angl_medDiff, beau_medDiff, conr_medDiff, galv_medDiff, hous_medDiff, clvl_medDiff, 
         hiol_medDiff, hsea_medDiff, hsin_medDiff, hnts_medDiff, ptar_medDiff, rbrw_medDiff, 
         sbol_medDiff, srgt_medDiff, txpt_medDiff]
OutputDF = pd.DataFrame(np.column_stack((means, medians)), columns=["mean", "median"], 
                        index=["Angleton", "Beaumont", "Conroe", "Galveston", "Houston",
                               "Cleveland", "High Island Oil", "Houston Executive Airport",
                               "Houston Intercontinental Airport", "Huntsville", 
                               "Port Arthur", "Robert R Wells", "Sabine Oil", "Sargent", "Texas Point"])
OutputDF.to_csv("../../03ProcessedData/ERA5Errors.csv")

# %%
#Instead organize it so we can see more of what these errors look like
days=['Mar23_00', 'Mar23_03', 'Mar23_06', 'Mar23_09','Mar23_12', 'Mar23_15','Mar23_18', 'Mar23_21',
      'Mar24_00', 'Mar24_03', 'Mar24_06', 'Mar24_09','Mar24_12', 'Mar24_15','Mar24_18', 'Mar24_21',
      'Mar25_00', 'Mar25_03', 'Mar25_06', 'Mar25_09','Mar25_12', 'Mar25_15','Mar25_18', 'Mar25_21',
      'Mar26_00', 'Mar26_03', 'Mar26_06', 'Mar26_09','Mar26_12', 'Mar26_15','Mar26_18', 'Mar26_21',
      'Mar27_00', 'Mar27_03', 'Mar27_06', 'Mar27_09','Mar27_12', 'Mar27_15','Mar27_18', 'Mar27_21',
      'Mar28_00', 'Mar28_03', 'Mar28_06', 'Mar28_09','Mar28_12', 'Mar28_15','Mar28_18', 'Mar28_21',
      'Mar29_00', 'Mar29_03', 'Mar29_06', 'Mar29_09','Mar29_12', 'Mar29_15','Mar29_18', 'Mar29_21',
      'Mar30_00', 'Mar30_03', 'Mar30_06', 'Mar30_09','Mar30_12', 'Mar30_15','Mar30_18', 'Mar30_21',
      'Mar31_00', 'Mar31_03', 'Mar31_06', 'Mar31_09','Mar31_12', 'Mar31_15','Mar31_18', 'Mar31_21',
      'Apr01_00', 'Apr01_03', 'Apr01_06', 'Apr01_09','Apr01_12', 'Apr01_15','Apr01_18', 'Apr01_21', 
      'Apr02_00', 'Apr02_03', 'Apr02_06', 'Apr02_09','Apr02_12', 'Apr02_15','Apr02_18', 'Apr02_21',
      'Apr03_00']
OutputDF = pd.DataFrame(np.column_stack((days, [*angl_marDiffs, *angl_aprDiffs], [*conr_marDiffs, *conr_aprDiffs], 
                                         [*galv_marDiffs, *galv_aprDiffs], [*hous_marDiffs, *hous_aprDiffs], [*clvl_marDiffs, *clvl_aprDiffs],
                                         [*hiol_marDiffs, *hiol_aprDiffs], [*hsea_marDiffs, *hsea_aprDiffs], [*hsin_marDiffs, *hsin_aprDiffs], 
                                        [*hnts_marDiffs, *hnts_aprDiffs], [*ptar_marDiffs, *ptar_aprDiffs], [*rbrw_marDiffs, *rbrw_aprDiffs], 
                                        [*sbol_marDiffs, *sbol_aprDiffs], [*srgt_marDiffs, *srgt_aprDiffs], [*txpt_marDiffs, *txpt_aprDiffs])), 
                        columns=["Days", "Angleton Lake Jackson", "Conroe", "Galveston", "Houston", "Cleveland", "High Island Oil", "Houston Executive Airport",
                               "Houston Intercontinental Airport", "Huntsville", "Port Arthur", "Robert R Wells", "Sabine Oil", "Sargent", "Texas Point"])

OutputDF.to_csv("../../03ProcessedData/ERA5Errors_byday.csv")
